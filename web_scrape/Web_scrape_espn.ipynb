# %%
from bs4 import BeautifulSoup
import urllib

# %%
r = urllib.urlopen('http://stats.espncricinfo.com/ci/engine/stats/index.html?class=3;home_or_away=1;home_or_away=2;home_or_away=3;result=1;result=2;result=3;result=5;spanmax1=29+Mar+2017;spanmin1=29+Mar+2014;spanval1=span;team=6;template=results;type=batting').read()
soup = BeautifulSoup(r)

# %%
print type(soup)
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
print type(soup.prettify())
# Out:
# <type 'unicode'>

# %%
letters = soup.find_all("tr", class_="data1")
letters = list(letters)
print letters[0]
# Out:
# <tr class="data1">
# <td class="left" nowrap="nowrap"><a class="data-link" href="/ci/content/player/253802.html">V Kohli</a></td>
# <td class="left" nowrap="nowrap">2014-2017</td>
# <td>24</td>
# <td>22</td>
# <td>8</td>
# <td><b>975</b></td>
# <td>90*</td>
# <td>69.64</td>
# <td>695</td>
# <td>140.28</td>
# <td>0</td>
# <td>10</td>
# <td>0</td>
# <td>98</td>
# <td>21</td>
# <td class="padDD"><a href="javascript:void(0)" onmouseout="menuLayers.hide()" onmouseover="menuLayers.show('engine-dd1', event); window.status='investigate this query'; return true"><img alt="investigate this query" border="0" height="11" src="http://i.imgci.com/espncricinfo/guruInvestigate.gif" width="11"/></a></td>
# </tr>

# %%
print (letters[0])
test = str(letters[0])
# print (letters[1])
# Out:
# <tr class="data1">
# <td class="left" nowrap="nowrap"><a class="data-link" href="/ci/content/player/253802.html">V Kohli</a></td>
# <td class="left" nowrap="nowrap">2014-2017</td>
# <td>24</td>
# <td>22</td>
# <td>8</td>
# <td><b>975</b></td>
# <td>90*</td>
# <td>69.64</td>
# <td>695</td>
# <td>140.28</td>
# <td>0</td>
# <td>10</td>
# <td>0</td>
# <td>98</td>
# <td>21</td>
# <td class="padDD"><a href="javascript:void(0)" onmouseout="menuLayers.hide()" onmouseover="menuLayers.show('engine-dd1', event); window.status='investigate this query'; return true"><img alt="investigate this query" border="0" height="11" src="http://i.imgci.com/espncricinfo/guruInvestigate.gif" width="11"/></a></td>
# </tr>

# %%
lobbying = {}
for elements in letters:
    print (elements)
    lobbying[elements.a.get_text()]=[elements.td.get_text()]
# Out:
# <tr class="data1">
# <td class="left" nowrap="nowrap"><a class="data-link" href="/ci/content/player/253802.html">V Kohli</a></td>
# <td class="left" nowrap="nowrap">2014-2017</td>
# <td>24</td>
# <td>22</td>
# <td>8</td>
# <td><b>975</b></td>
# <td>90*</td>
# <td>69.64</td>
# <td>695</td>
# <td>140.28</td>
# <td>0</td>
# <td>10</td>
# <td>0</td>
# <td>98</td>
# <td>21</td>
# <td class="padDD"><a href="javascript:void(0)" onmouseout="menuLayers.hide()" onmouseover="menuLayers.show('engine-dd1', event); window.status='investigate this query'; return true"><img alt="investigate this query" border="0" height="11" src="http://i.imgci.com/espncricinfo/guruInvestigate.gif" width="11"/></a></td>
# </tr>
# <tr class="data1">
# <td class="left" nowrap="nowrap"><a class="data-link" href="/ci/content/player/34102.html">RG Sharma</a></td>
# <td class="left" nowrap="nowrap">2014-2016</td>
# <td>23</td>
# <td>23</td>
# <td>1</td>
# <td><b>683</b></td>
# <td class="padAst">106</td>
# <td>31.04</td>
# ...

# %%
main = []
for strong_tag in soup.find_all('tr'):
    main.append(strong_tag.text.replace('\n',' '))
# for j in main:
#     print j
apt_data = main[7:-10]

# %%
Player,Span,Mat,Inns,NO,Runs,HS,Ave,BF,SR,century,half_century,zero,four,six = ([] for i in range(15))

# %%
column_data = apt_data[0].encode('utf-8').split()
masterdict = [column_data]

for k in apt_data[1:]:
    play_list = k.strip().encode('utf-8').split()
    player = play_list[0]+' '+play_list[1]
    masterdict.append(play_list[1:])

# %%
import csv
with open("Australia.csv", "wb") as f:
    writer = csv.writer(f)
    writer.writerows(masterdict)

# %%
cricdata = pd.read_csv('Australia.csv')
print cricdata
# Out:
#       Player       Span  Mat Inns  NO Runs    HS    Ave   BF      SR 100  50  \
# 0      Kohli  2014-2017   24   22   8  975   90*  69.64  695  140.28   0  10
# 1     Sharma  2014-2016   23   23   1  683   106  31.04  510  133.92   1   4
# 2      Dhoni  2014-2017   30   25  16  415    56  46.11  295  140.67   0   1
# 3      Raina  2014-2017   25   20   2  412    63  22.88  324  127.16   0   1
# 4     Dhawan  2014-2016   17   17   2  348    60  23.20  300  116.00   0   2
# 5      Singh  2014-2017   21   17   3  298    60  21.28  275  108.36   0   1
# 6      Rahul  2016-2017    8    7   2  280  110*  56.00  186  150.53   1   1
# 7     Rahane  2014-2016   13   13   2  201    40  18.27  189  106.34   0   0
# 8     Pandey  2015-2017    8    6   0  100    48  16.66   89  112.35   0   0
# 9     Pandya  2016-2017   19   10   0  100    31  10.00   75  133.33   0   0
# 10    Jadhav  2015-2016    5    4   0   91    58  22.75   68  133.82   0   1
# ...
